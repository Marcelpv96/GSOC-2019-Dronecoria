# %%
import glob
from PIL import Image
import numpy as np

# %%
def percentatge()

# %%
images_name = glob.glob("burnt/*.jpg")
i=0
for image_name in images_name:
    if (948, 812) != Image.open(image_name).size:
        i+=1
        print(i)

# %%
segmentation_tf = glob.glob("segmented_tf/*.png")
equivalence = []
for image in segmentation_tf:
    arr_image = np.array(Image.open(image).convert('RGB'))
    total_size = arr_image.shape[0]*arr_image.shape[1]
    class1 = arr_image[np.all(arr_image != np.array((0,0,0)).reshape(1,1,3),axis=2)].shape[0]
    class0 = total_size - class1
    equivalence += [(class0 / total_size *100 ) ,(class1/total_size*100)]

# %%
print(equivalence)
# Out:
# [87.96117312049219, 12.038826879507806, 84.09303485689344, 15.906965143106566, 87.32930099145726, 12.670699008542746, 87.86140383696036, 12.138596163039637, 82.50296190060486, 17.497038099395148, 86.73068529026627, 13.26931470973374, 88.8590966722787, 11.140903327721311, 87.49558313067698, 12.504416869323023, 85.63322317141609, 14.3667768285839, 90.95425162644717, 9.045748373552826, 89.85678950759701, 10.143210492402984, 91.55286732763817, 8.44713267236183, 87.29604456361331, 12.703955436386687, 88.62630167737107, 11.37369832262892, 92.01845731745338, 7.9815426825466105, 88.62630167737107, 11.37369832262892, 92.849868013552, 7.150131986448005, 89.85678950759701, 10.143210492402984, 92.01845731745338, 7.9815426825466105, 83.67109392862339, 16.328906071376608, 95.54156014217124, 4.458439857828771, 85.59996674357215, 14.400033256427843, 88.46001953815136, 11.539980461848643, 91.85217517823367, 8.147824821766331, 95.31084367400386, 4.689156325996134, 86.29835172829499, 13.701648271705016
# ...
